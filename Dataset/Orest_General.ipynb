# %%
import pandas as pd

# %%
data = pd.read_csv('Практика/Udemy_General.csv')

# %%
data
# Out:
#                                                    Title  \
# 0      2020 Complete Python Bootcamp: From Zero to He...
# 1                             The Web Developer Bootcamp
# 2      Machine Learning A-Z™: Hands-On Python & R In ...
# 3            Angular - The Complete Guide (2020 Edition)
# 4      Java Programming Masterclass for Software Deve...
# ...                                                  ...
# 44566     Business Basics for Professional Entrepreneurs
# 44567       How to Trend on Skillshare without Followers
# 44568  Betting Basics - How to become profitable on s...
# 44569      Level 1 2014 CFA® Program – Corporate Finance
# 44570                           Storytelling In Business
#
#                                                  Summary  Enrollment  Stars  \
# 0      Learn Python like a Professional! Start from t...     1100093    4.6
# 1      The only course you need to learn web developm...      596726    4.6
# ...

# %%
data.sort_values(['Stars', 'Rating'], ascending=(False, False)).head()
#Тайтли з найвищим рейтингом і зіркою?
# Out:
#                                                    Title  \
# 1274   Learn Swift 4 with Bob: The Intermediate to Ad...
# 24986  Learn the "Hand-Painted" texturing style for v...
# 31527               Pipeline Completo Arte 3D para Games
# 31546  建網進階篇-製作您自己的WordPress主題使用HTML,CSS,php,mySQL,Bo...
# 31558               「打造你的影像硬底子」James給所有Photoshop使用者的第一堂課
#
#                                                  Summary  Enrollment  Stars  \
# 1274   Functional Programming, Protocol Oriented, Val...        1538    5.0
# 24986  How to texture weapons and assets for your gam...       25782    5.0
# 31527         Criação de um Asset no padrão de games AAA         718    5.0
# 31546                                      建立一個真實動態網站全過程        2814    5.0
# 31558  華人界的知名Photoshop教學書作者游閔州所推出的線上課程。適合初學者到進階使用者，攝影...         635    5.0
#
#        Rating                                               Link Category
# 1274      572  https://www.udemy.com/course/learn-swift-with-...     Tech
# ...

# %%
data.columns
# Out:
# Index(['Title', 'Summary', 'Enrollment', 'Stars', 'Rating', 'Link',
#        'Category'],
#       dtype='object')

# %%
data.describe()
# Out:
#          Enrollment         Stars         Rating
# count  4.457100e+04  44571.000000   44571.000000
# mean   3.959032e+03      3.869200     315.715667
# std    1.572454e+04      1.109995    2957.970475
# min    0.000000e+00      0.000000       0.000000
# 25%    7.500000e+01      3.700000       8.000000
# 50%    5.760000e+02      4.200000      27.000000
# 75%    2.742000e+03      4.500000      99.000000
# max    1.100093e+06      5.000000  318066.000000

# %%
data[data.Category == 'Tech']
# з категорією Tech
# Out:
#                                                   Title  \
# 0     2020 Complete Python Bootcamp: From Zero to He...
# 1                            The Web Developer Bootcamp
# 2     Machine Learning A-Z™: Hands-On Python & R In ...
# 3           Angular - The Complete Guide (2020 Edition)
# 4     Java Programming Masterclass for Software Deve...
# ...                                                 ...
# 9959  MonoDevelop/Visual Studio Mac & Unity ; Pro Ti...
# 9960                     Unity Game Tutorial: Tetris 3D
# 9961      Spring 5.0 Project: Building a Travel Website
# 9962  Guide to Powershell 6 and Automating Active Di...
# 9963  The Complete Express.js Developer Course & Cre...
#
#                                                 Summary  Enrollment  Stars  \
# 0     Learn Python like a Professional! Start from t...     1100093    4.6
# 1     The only course you need to learn web developm...      596726    4.6
# ...
