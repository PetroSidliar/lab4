# %%
import pandas as pd

# %%
data = pd.read_csv('Практика/Udemy_Lifestyle.csv')

# %%
data
# Out:
#             id                                              title  \
# 0       793796  Microsoft Excel - Excel from Beginner to Advanced
# 1       516446  Microsoft Excel - Advanced Excel Formulas & Fu...
# 2      1506888                  Unlock Excel VBA and Excel Macros
# 3       977438  Microsoft Excel - Data Analysis with Excel Piv...
# 4       948866  Excel Essentials: The Complete Excel Series - ...
# ...        ...                                                ...
# 39684  3445012  Come Creare il Cartamodello per alcuni capi d'...
# 39685  2053885                       Первые принципы христианства
# 39686  3451474  Come Creare le Varianti di un Abito a Tubino 2...
# 39687  2070127  Come Creare il Cartamodello per Pantaloni da D...
# 39688  3548450  Geburtstagsparty ohne Stress zu Hause vorbereiten
#
#                                                      url  is_paid  \
# 0      /course/microsoft-excel-2013-from-beginner-to-...     True
# ...

# %%
rows, cols = data.shape

# %%
data.shape
# Out:
# (39689, 20)

# %%
data.columns
# Out:
# Index(['id', 'title', 'url', 'is_paid', 'num_subscribers', 'avg_rating',
#        'avg_rating_recent', 'rating', 'num_reviews', 'is_wishlisted',
#        'num_published_lectures', 'num_published_practice_tests', 'created',
#        'published_time', 'discount_price__amount', 'discount_price__currency',
#        'discount_price__price_string', 'price_detail__amount',
#        'price_detail__currency', 'price_detail__price_string'],
#       dtype='object')

# %%
data.sort_values(['price_detail__price_string', 'rating'], ascending=(True, False)).head()['title']
#Найдешевші курси з найвищим рейтингом
# Out:
# 1710                       ASANA 2020 - Basic to advanced
# 2055    Complete Guide To New Google Sites - Build You...
# 2060    Excel MIS Analytics (Advance Vlookup Match & I...
# 2081               Excel in Microsoft Excel 2013: Part II
# 2083    Connect XL & Outlook -Access VBA & Collection ...
# Name: title, dtype: object

# %%
data['trust_score'] = data['num_reviews'] / data['rating']
data.head()
# Out:
#         id                                              title  \
# 0   793796  Microsoft Excel - Excel from Beginner to Advanced
# 1   516446  Microsoft Excel - Advanced Excel Formulas & Fu...
# 2  1506888                  Unlock Excel VBA and Excel Macros
# 3   977438  Microsoft Excel - Data Analysis with Excel Piv...
# 4   948866  Excel Essentials: The Complete Excel Series - ...
#
#                                                  url  is_paid  \
# 0  /course/microsoft-excel-2013-from-beginner-to-...     True
# 1                        /course/excel-for-analysts/     True
# 2               /course/excel-vba-and-macros-course/     True
# 3     /course/data-analysis-with-excel-pivot-tables/     True
# 4  /course/excel-essentials-the-complete-series-l...     True
#
#    num_subscribers  avg_rating  avg_rating_recent   rating  num_reviews  \
# 0           555082     4.60192            4.60676  4.60676       172869
# ...

# %%
data.sort_values(['price_detail__price_string', 'trust_score'], ascending=(True, False)).head()
#Найдешевші курси з найвищим рейтингом
# Out:
#             id                                              title  \
# 4742     38266                       The Secrets of Body Language
# 13691  1081714    Drawing and Painting on the iPad with Procreate
# 4750   1436164         Customer Service: Soft Skills Fundamentals
# 32456  1768990  Counter-Strike: Global Offensive — Play Like a...
# 4762   1116388          How to Build Confidence in Your Abilities
#
#                                                      url  is_paid  \
# 4742       /course/the-secrets-of-body-language-webinar/     True
# 13691  /course/drawing-and-painting-on-the-ipad-with-...     True
# 4750   /course/customer-service-soft-skills-fundament...     True
# 32456  /course/counter-strike-global-offensive-play-l...     True
# 4762   /course/how-to-build-confidence-in-your-abilit...     True
#
#        num_subscribers  avg_rating  avg_rating_recent   rating  num_reviews  \
# 4742             55608     4.42458            4.40152  4.40152        15952
# ...

# %%
data.sort_values(['rating', 'num_subscribers'], ascending=(False,False)).head()
#Курси з найвищим рейтингом і найбільшою кількістю підписників
# Out:
#             id                                              title  \
# 14907  1184318  After Effects CC: Animating Text Titles For Be...
# 13877   381524  UI Design with Photoshop from Beginner to Expe...
# 13506  3581955  Gain Love Relationship Skills Life Coaching Co...
# 26993  3150376  Space Render 2.0: Transform your podcast into ...
# 27416  3278788               UDEMY: Make Money Online. Unofficial
#
#                                                      url  is_paid  \
# 14907          /course/aftereffects-lower-thirds-titles/     True
# 13877  /course/learn-photoshop-for-ui-design-from-scr...     True
# 13506  /course/get-a-relationship-life-coaching-love-...     True
# 26993  /course/space-render-20-transform-your-podcast...     True
# 27416         /course/start-selling-on-udemy-in-2-hours/     True
#
#        num_subscribers  avg_rating  avg_rating_recent  rating  num_reviews  \
# 14907            12768         5.0                5.0     5.0          101
# ...

# %%
data[data.num_subscribers >= 2500].sort_values(['price_detail__price_string', 'rating'], ascending=(True, False)).head()
#найдешевші курси з найвищим рейтингом, де не менше 2500 підписників
# Out:
#             id                                              title  \
# 26993  3150376  Space Render 2.0: Transform your podcast into ...
# 27416  3278788               UDEMY: Make Money Online. Unofficial
# 14985   798274  Animation in Photoshop: Create an Amazing Moti...
# 7740    343196  Wedding Speech: You Can Give a Fantastic Weddi...
# 3057   2222644  Microsoft Excel: En Sık Kullanılan 40 Formül U...
#
#                                                      url  is_paid  \
# 26993  /course/space-render-20-transform-your-podcast...     True
# 27416         /course/start-selling-on-udemy-in-2-hours/     True
# 14985  /course/animate-via-photoshop-create-an-amazin...     True
# 7740               /course/how-to-give-a-wedding-speech/     True
# 3057   /course/microsoft-excel-en-sk-kullanlan-40-for...     True
#
#        num_subscribers  avg_rating  avg_rating_recent   rating  num_reviews  \
# 26993             3738        5.00            5.00000  5.00000            3
# ...

# %%
data.sort_values('price_detail__price_string', ascending=False).head()
# Out:
#             id                                              title  \
# 7098    163706  Productivity and Time Management Techniques & ...
# 38327  3260312            Viver de Café - Curso Básico de Barista
# 13775   396204  Graphic Design Masterclass: Learn Graphic Desi...
# 38466  2399312                                         幻顏電眼-進階彩妝課
# 26088  1872728  Expert DIY Pardot Implementation & Training Co...
#
#                                                      url  is_paid  \
# 7098   /course/productivity-time-management-technique...     True
# 38327  /course/viver-de-cafe-curso-basico-de-barista-...     True
# 13775                            /course/graphic-design/     True
# 38466                      /course/tomokoadvancedmakeup/     True
# 26088              /course/pardot-implementation-course/     True
#
#        num_subscribers  avg_rating  avg_rating_recent   rating  num_reviews  \
# 7098               154     4.00000            3.93401  3.93401           29
# ...
